# %% [markdown]
# # Import libraries and data files

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_DEC = pd.read_excel("JMR_data-2019-12.xlsx")
data_NOV = pd.read_excel("JMR_data-2019-11.xlsx")
data_OCT = pd.read_excel("JMR_data-2019-10.xlsx")
data_SEP = pd.read_excel("JMR_data-2019-09.xlsx")
data_AUG = pd.read_excel("JMR_data-2019-08.xlsx")
data_JUL = pd.read_excel("JMR_data-2019-07.xlsx")
data_JUN = pd.read_excel("JMR_data-2019-06.xlsx")
data_MAY = pd.read_excel("JMR_data-2019-05.xlsx")
data_APR = pd.read_excel("JMR_data-2019-04.xlsx")
data_MAR = pd.read_excel("LPR_data-2019-03.xlsx")
data_FEB = pd.read_excel("LPR_data-2019-02.xlsx")
data_JAN = pd.read_excel("LPR_data-2019-01.xlsx")
data_12_18 = pd.read_excel("LPR_data-2018-12.xlsx")
data_11_18 = pd.read_excel("LPR_data-2018-11.xlsx")
data_10_18 = pd.read_excel("LPR_data-2018-10.xlsx")
data_09_18 = pd.read_excel("LPR_data-2018-09.xlsx")
data_08_18 = pd.read_excel("LPR_data-2018-08.xlsx")
data_07_18 = pd.read_excel("LPR_data-2018-07.xlsx")
data_06_18 = pd.read_excel("LPR_data-2018-06.xlsx")
data_05_18 = pd.read_excel("LPR_data-2018-05.xlsx")
data_04_18 = pd.read_excel("LPR_data-2018-04.xlsx")
data_02_18 = pd.read_excel("LPR_data-2018-02.xlsx")
data_01_18 = pd.read_excel("LPR_data-2018-01.xlsx")
data_12_17 = pd.read_excel("LPR_data-2017-12.xlsx")
data_11_17 = pd.read_excel("LPR_data-2017-11.xlsx")
data_10_17 = pd.read_excel("LPR_data-2017-10.xlsx")
data_09_17 = pd.read_excel("LPR_data-2017-09.xlsx")
data_08_17 = pd.read_excel("LPR_data-2017-08.xlsx")
data_07_17 = pd.read_excel("LPR_data-2017-07.xlsx")

# %%
frames = [data_07_17, data_08_17, data_09_17, data_10_17, data_11_17, data_12_17, data_01_18,
          data_02_18, data_04_18, data_05_18, data_06_18, data_07_18, data_08_18, data_09_18,
          data_10_18, data_11_18, data_12_18, data_JAN, data_FEB, data_MAR, data_APR, data_MAY, data_JUN, 
          data_JUL, data_AUG, data_SEP, data_OCT, data_NOV, data_DEC]

# %%
df = pd.concat(frames)

# %%
df
# Out:
#               Metro Dimension Type    Month         Dimension  \
# 0          National    Quick Facts  2017-07   U.S. Median Pay
# 1           Atlanta    Quick Facts  2017-07  Metro Median Pay
# 2           Atlanta    Quick Facts  2017-07   U.S. Median Pay
# 3           Atlanta    Quick Facts  2017-07      Job Openings
# 4           Atlanta    Quick Facts  2017-05  Labor Force Size
# ...             ...            ...      ...               ...
# 4987  Washington DC   Company Size  2019-12             5000+
# 4988  Washington DC   Company Size  2019-12          501-1000
# 4989  Washington DC   Company Size  2019-12            51-200
# 4990  Washington DC   Company Size  2019-12               <51
# 4991  Washington DC   Company Size  2019-12               NaN
#
#                Measure      Value        YoY
# 0      U.S. Median Pay   $ 51,120       1.2%
# 1     Metro Median Pay   $ 52,921       0.9%
# 2      U.S. Median Pay   $ 51,120       1.2%
# ...

# %%
df.Dimension.unique()
# Out:
# array(['U.S. Median Pay', 'Metro Median Pay', 'Job Openings',
#        'Labor Force Size', 'Total Employment', 'Unemployment Rate',
#        'Software Engineer', 'Programmer Analyst', 'Consultant',
#        'Project Manager', 'Store Manager', 'Business Analyst', 'Cashier',
#        'Financial Analyst', 'Administrative Assistant', 'Accountant',
#        'Sales Representative', 'Professor', 'Registered Nurse',
#        'Marketing Manager', 'Operations Manager', 'Product Manager',
#        'Sales Manager', 'Teacher', 'Bank Teller',
#        'Customer Service Manager', 'Physical Therapist',
#        'Mechanical Engineer', 'Recruiter', 'Design Engineer',
#        'Pharmacy Technician', 'Graphic Designer', 'Web Developer',
#        'Business Development Manager', 'Data Scientist', 'Buyer',
#        'Data Analyst', 'Electrical Engineer', 'Attorney',
#        'Human Resources Manager', 'Technician', 'Restaurant Cook',
#        'Production Manager', 'Manufacturing Engineer',
# ...

# %%
df.Metro.unique()
# Out:
# array(['National', 'Atlanta', 'New York City', 'Los Angeles',
#        'Philadelphia', 'Houston', 'Seattle', 'San Francisco', 'Chicago',
#        'Boston', 'Washington DC', 'New-York-City', 'Los-Angeles',
#        'San-Francisco', 'Washington-DC', 'U.S.'], dtype=object)

# %%
# function converts salaries to floats, concerts YOY to float, and fixes duplicate city names
def clean_variables():
    df["Value"] = df[df.columns[5:6]].replace('[\$,]', '', regex=True)
    df["Value"] = df[df.columns[5:6]].replace('[\%,]', '', regex=True).astype(float)
    df["YoY"] = df[df.columns[6:]].replace('[\%,]', '', regex=True).astype(float)
    df["Metro"] = df["Metro"].replace("New-York-City", "New York City")
    df["Metro"] = df["Metro"].replace("San-Francisco", "San Francisco")
    df["Metro"] = df["Metro"].replace("Los-Angeles", "Los Angeles")
    df["Metro"] = df["Metro"].replace("Washington-DC", "Washington DC")

# %%
clean_variables()

# %%
# confirm duplicate metros were cleaned and are combined
df.Metro.unique()
# Out:
# array(['National', 'Atlanta', 'New York City', 'Los Angeles',
#        'Philadelphia', 'Houston', 'Seattle', 'San Francisco', 'Chicago',
#        'Boston', 'Washington DC', 'U.S.'], dtype=object)

# %% [markdown]
# # City Separation

# %%
# Create separate data frames for each metro area and national
df_SEA = df[df["Metro"] == "Seattle"]
df_NYC = df[df["Metro"] == "New York City"]
df_LA = df[df["Metro"] == "Los Angeles"]
df_PHIL = df[df["Metro"] == "Philadelphia"]
df_SF = df[df["Metro"] == "San Francisco"]
df_CHI = df[df["Metro"] == "Chicago"]
df_BOS = df[df["Metro"] == "Boston"]
df_DC = df[df["Metro"] == "Washington DC"]
df_US = df[df["Metro"] == "National"]
df_ATL = df[df["Metro"] == "Atlanta"]
df_HOU = df[df["Metro"] == "Houston"]

# %% [markdown]
# ## Teacher Separation

# %%
# Create data frames for teachers in each region
df_SEA_Teacher = df_SEA[df_SEA["Dimension"] == "Teacher"]
df_US_Teacher = df_US[df_US["Dimension"] == "Teacher"]
df_ATL_Teacher = df_ATL[df_ATL["Dimension"] == "Teacher"]
df_HOU_Teacher = df_HOU[df_HOU["Dimension"] == "Teacher"]
df_NYC_Teacher = df_NYC[df_NYC["Dimension"] == "Teacher"]
df_LA_Teacher = df_LA[df_LA["Dimension"] == "Teacher"]
df_PHIL_Teacher = df_PHIL[df_PHIL["Dimension"] == "Teacher"]
df_SF_Teacher = df_SF[df_SF["Dimension"] == "Teacher"]
df_CHI_Teacher = df_CHI[df_CHI["Dimension"] == "Teacher"]
df_BOS_Teacher = df_BOS[df_BOS["Dimension"] == "Teacher"]
df_DC_Teacher = df_DC[df_DC["Dimension"] == "Teacher"]

# %% [markdown]
# ## IT Manager Separation

# %%
# Create data frames for IT managers in each region
df_SEA_IT_Manager = df_SEA[df_SEA["Dimension"] == "IT Manager"]
df_US_IT_Manager = df_US[df_US["Dimension"] == "IT Manager"]
df_ATL_IT_Manager = df_ATL[df_ATL["Dimension"] == "IT Manager"]
df_HOU_IT_Manager = df_HOU[df_HOU["Dimension"] == "IT Manager"]
df_NYC_IT_Manager = df_NYC[df_NYC["Dimension"] == "IT Manager"]
df_LA_IT_Manager = df_LA[df_LA["Dimension"] == "IT Manager"]
df_PHIL_IT_Manager = df_PHIL[df_PHIL["Dimension"] == "IT Manager"]
df_SF_IT_Manager = df_SF[df_SF["Dimension"] == "IT Manager"]
df_CHI_IT_Manager = df_CHI[df_CHI["Dimension"] == "IT Manager"]
df_BOS_IT_Manager = df_BOS[df_BOS["Dimension"] == "IT Manager"]
df_DC_IT_Manager = df_DC[df_DC["Dimension"] == "IT Manager"]

# %% [markdown]
# ## Data Scientist Separation

# %%
# Create data frames for Data Scientists in each region
df_SEA_Data_Scientist = df_SEA[df_SEA["Dimension"] == "Data Scientist"]
df_US_Data_Scientist = df_US[df_US["Dimension"] == "Data Scientist"]
df_ATL_Data_Scientist = df_ATL[df_ATL["Dimension"] == "Data Scientist"]
df_HOU_Data_Scientist = df_HOU[df_HOU["Dimension"] == "Data Scientist"]
df_NYC_Data_Scientist = df_NYC[df_NYC["Dimension"] == "Data Scientist"]
df_LA_Data_Scientist = df_LA[df_LA["Dimension"] == "Data Scientist"]
df_PHIL_Data_Scientist = df_PHIL[df_PHIL["Dimension"] == "Data Scientist"]
df_SF_Data_Scientist = df_SF[df_SF["Dimension"] == "Data Scientist"]
df_CHI_Data_Scientist = df_CHI[df_CHI["Dimension"] == "Data Scientist"]
df_BOS_Data_Scientist = df_BOS[df_BOS["Dimension"] == "Data Scientist"]
df_DC_Data_Scientist = df_DC[df_DC["Dimension"] == "Data Scientist"]

# %% [markdown]
# ## Professor Separation

# %%
# Create data frames for Professors in each region
df_SEA_Professor = df_SEA[df_SEA["Dimension"] == "Professor"]
df_US_Professor = df_US[df_US["Dimension"] == "Professor"]
df_ATL_Professor = df_ATL[df_ATL["Dimension"] == "Professor"]
df_HOU_Professor = df_HOU[df_HOU["Dimension"] == "Professor"]
df_NYC_Professor = df_NYC[df_NYC["Dimension"] == "Professor"]
df_LA_Professor = df_LA[df_LA["Dimension"] == "Professor"]
df_PHIL_Professor = df_PHIL[df_PHIL["Dimension"] == "Professor"]
df_SF_Professor = df_SF[df_SF["Dimension"] == "Professor"]
df_CHI_Professor = df_CHI[df_CHI["Dimension"] == "Professor"]
df_BOS_Professor = df_BOS[df_BOS["Dimension"] == "Professor"]
df_DC_Professor = df_DC[df_DC["Dimension"] == "Professor"]

# %% [markdown]
# ## Sales Representative

# %%
# Create data frames for Sales Representatives in each region
df_SEA_Sales_Rep = df_SEA[df_SEA["Dimension"] == "Sales Representative"]
df_US_Sales_Rep = df_US[df_US["Dimension"] == "Sales Representative"]
df_ATL_Sales_Rep = df_ATL[df_ATL["Dimension"] == "Sales Representative"]
df_HOU_Sales_Rep = df_HOU[df_HOU["Dimension"] == "Sales Representative"]
df_NYC_Sales_Rep = df_NYC[df_NYC["Dimension"] == "Sales Representative"]
df_LA_Sales_Rep = df_LA[df_LA["Dimension"] == "Sales Representative"]
df_PHIL_Sales_Rep = df_PHIL[df_PHIL["Dimension"] == "Sales Representative"]
df_SF_Sales_Rep = df_SF[df_SF["Dimension"] == "Sales Representative"]
df_CHI_Sales_Rep = df_CHI[df_CHI["Dimension"] == "Sales Representative"]
df_BOS_Sales_Rep = df_BOS[df_BOS["Dimension"] == "Sales Representative"]
df_DC_Sales_Rep = df_DC[df_DC["Dimension"] == "Sales Representative"]

# %% [markdown]
# ## Accountant

# %%
# Create data frames for Accountants in each region
df_SEA_Accountant = df_SEA[df_SEA["Dimension"] == "Accountant"]
df_US_Accountant = df_US[df_US["Dimension"] == "Accountant"]
df_ATL_Accountant = df_ATL[df_ATL["Dimension"] == "Accountant"]
df_HOU_Accountant = df_HOU[df_HOU["Dimension"] == "Accountant"]
df_NYC_Accountant = df_NYC[df_NYC["Dimension"] == "Accountant"]
df_LA_Accountant = df_LA[df_LA["Dimension"] == "Accountant"]
df_PHIL_Accountant = df_PHIL[df_PHIL["Dimension"] == "Accountant"]
df_SF_Accountant = df_SF[df_SF["Dimension"] == "Accountant"]
df_CHI_Accountant = df_CHI[df_CHI["Dimension"] == "Accountant"]
df_BOS_Accountant = df_BOS[df_BOS["Dimension"] == "Accountant"]
df_DC_Accountant = df_DC[df_DC["Dimension"] == "Accountant"]

# %% [markdown]
# ## Registered Nurse

# %%
# Create data frames for Registered Nurses in each region
df_SEA_RN = df_SEA[df_SEA["Dimension"] == "Registered Nurse"]
df_US_RN = df_US[df_US["Dimension"] == "Registered Nurse"]
df_ATL_RN = df_ATL[df_ATL["Dimension"] == "Registered Nurse"]
df_HOU_RN = df_HOU[df_HOU["Dimension"] == "Registered Nurse"]
df_NYC_RN = df_NYC[df_NYC["Dimension"] == "Registered Nurse"]
df_LA_RN = df_LA[df_LA["Dimension"] == "Registered Nurse"]
df_PHIL_RN = df_PHIL[df_PHIL["Dimension"] == "Registered Nurse"]
df_SF_RN = df_SF[df_SF["Dimension"] == "Registered Nurse"]
df_CHI_RN = df_CHI[df_CHI["Dimension"] == "Registered Nurse"]
df_BOS_RN = df_BOS[df_BOS["Dimension"] == "Registered Nurse"]
df_DC_RN = df_DC[df_DC["Dimension"] == "Registered Nurse"]

# %%
# Explore salary trend for Teachers in Seattle
x = df_SEA_Teacher.Month
y = df_SEA_Teacher.Value
plt.plot(x,y)
plt.xticks(rotation=90)
plt.ylabel('Salary ($)')
plt.title('Salary Trend for a Teacher in Seattle')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# Explore salary trend for IT Manager in Seattle
x = df_SEA_IT_Manager.Month
y = df_SEA_IT_Manager.Value
plt.plot(x,y)
plt.xticks(rotation=90)
plt.ylabel('Salary ($)')
plt.title('Salary Trend for an IT Manager in Seattle')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# # Job Title Separation

# %%
# Create dataframes for 12 job titles that includes all regions
df_IT_Manager = df[df["Dimension"] == "IT Manager"]
df_RN = df[df["Dimension"] == "Registered Nurse"]
df_Accountant = df[df["Dimension"] == "Accountant"]
df_Sales_Rep = df[df["Dimension"] == "Sales Representative"]
df_Professor = df[df["Dimension"] == "Professor"]
df_Data_Scientist = df[df["Dimension"] == "Data Scientist"]
df_Teacher = df[df["Dimension"] == "Teacher"]
df_Software_Engineer = df[df["Dimension"] == "Software Engineer"]
df_Project_Mgr = df[df["Dimension"] == "Project Manager"]
df_Financial_Analyst = df[df["Dimension"] == "Financial Analyst"]
df_Data_Analyst = df[df["Dimension"] == "Data Analyst"]
df_Graphic_Designer = df[df["Dimension"] == "Graphic Designer"]

# %%
# Calculate the mean salary of each job title
# This will be needed for the target variable
ITMgr_mean = int(df_IT_Manager.Value.mean())
RN_mean = int(df_RN.Value.mean())
Accountant_mean = int(df_Accountant.Value.mean())
SalesRep_mean = int(df_Sales_Rep.Value.mean())
Professor_mean = int(df_Professor.Value.mean())
DataScientist_mean = int(df_Data_Scientist.Value.mean())
Teadcher_mean = int(df_Teacher.Value.mean())
SoftwareEng_mean = int(df_Software_Engineer.Value.mean())
ProjectMgr_mean = int(df_Project_Mgr.Value.mean())
FinAnalyst_mean = int(df_Financial_Analyst.Value.mean())
DataAnalyst_mean = int(df_Data_Analyst.Value.mean())
GraphicDesigner_mean = int(df_Graphic_Designer.Value.mean())

# %% [markdown]
# # Dec 2019 Separation

# %%
# Create dataframes for different positions for the month of December 2019
df_IT_Manager_1219 = df_IT_Manager[df_IT_Manager["Month"] == "2019-12"]
df_RN_1219 = df_RN[df_RN["Month"] == "2019-12"]
df_Accountant_1219 = df_Accountant[df_Accountant["Month"] == "2019-12"]
df_Sales_Rep_1219 = df_Sales_Rep[df_Sales_Rep["Month"] == "2019-12"]
df_Professor_1219 = df_Professor[df_Professor["Month"] == "2019-12"]
df_Data_Scientist_1219 = df_Data_Scientist[df_Data_Scientist["Month"] == "2019-12"]
df_Teacher_1219 = df_Teacher[df_Teacher["Month"] == "2019-12"]

# %%
# Plot the salaries for IT Manager for Dec 2019 across regions
import numpy as np

objects = df_IT_Manager_1219.Metro
y_pos = np.arange(len(objects))
performance = df_IT_Manager_1219.Value

plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects, rotation=90)
plt.ylabel('Salary ($)')
plt.title('Dec 2019 IT Manager Salary')

plt.show()

# %%
# Compare YoY values for Dec 2019 IT Manager across regions
objects = df_IT_Manager_1219.Metro
y_pos = np.arange(len(objects))
performance = df_IT_Manager_1219.YoY

plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects, rotation=90)
plt.ylabel('Salary Change Year over Year (%)')
plt.title('Dec 2019 IT Manager Salary')

plt.show()

# %% [markdown]
# # Compare Regions

# %%
# Compare Seattle Teacher salary to National Average
x = df_SEA_Teacher.Month
y = df_SEA_Teacher.Value
z = df_US_Teacher.Value
plt.plot(x,y, color='blue')
plt.plot(x,z, color='red')
plt.xticks(rotation=90)
plt.ylabel('Salary ($)')
plt.title('Salary Trend for a Teacher in Seattle')
plt.legend(['Seattle', 'National Average'])
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# Compare several Teacher salaries to National Average
x = df_SEA_Teacher.Month
y = df_SEA_Teacher.Value
z = df_US_Teacher.Value
a = df_ATL_Teacher.Value
b = df_HOU_Teacher.Value
plt.plot(x,y, color='blue')
plt.plot(x,z, color='red')
plt.plot(x,a, color='green')
plt.plot(x,b, color='yellow')
plt.xticks(rotation=90)
plt.ylabel('Salary ($)')
plt.title('Salary Trend for a Teacher')
plt.legend(['Seattle', 'National Average', 'Atlanta', 'Houston'])
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# Compare IT Manager salary trends across regions
x = df_SEA_IT_Manager.Month
y = df_SEA_IT_Manager.Value
z = df_US_IT_Manager.Value
a = df_ATL_IT_Manager.Value
b = df_HOU_IT_Manager.Value
c = df_NYC_IT_Manager.Value
d = df_LA_IT_Manager.Value
e = df_PHIL_IT_Manager.Value
f = df_SF_IT_Manager.Value
g = df_CHI_IT_Manager.Value
h = df_BOS_IT_Manager.Value
i = df_DC_IT_Manager.Value

plt.plot(x,y, color='blue')
plt.plot(x,z, color='red')
plt.plot(x,a, color='green')
plt.plot(x,b, color='yellow')
plt.plot(x,c, color='pink')
plt.plot(x,d, color='orange')
plt.plot(x,e, color='purple')
plt.plot(x,f, color='black')
plt.plot(x,g, color='gray')
plt.plot(x,h, color='gold')
plt.plot(x,i, color='brown')

plt.xticks(rotation=90)
plt.ylabel('Salary ($)')
plt.title('Salary Trend for an IT Manager')
plt.legend(['Seattle', 'National Average', 'Atlanta', 'Houston', 'NYC', 'LA', 'Philadelphia', 'SF', 'Chicago', 'Boston', 'Washington D.C.'],loc='center left', bbox_to_anchor=(1, 0.5))
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# Compare Registered Nurse salary trends across regions
x = df_SEA_RN.Month
y = df_SEA_RN.Value
z = df_US_RN.Value
a = df_ATL_RN.Value
b = df_HOU_RN.Value
c = df_NYC_RN.Value
d = df_LA_RN.Value
e = df_PHIL_RN.Value
f = df_SF_RN.Value
g = df_CHI_RN.Value
h = df_BOS_RN.Value
i = df_DC_RN.Value

plt.plot(x,y, color='blue')
plt.plot(x,z, color='red')
plt.plot(x,a, color='green')
plt.plot(x,b, color='yellow')
plt.plot(x,c, color='pink')
plt.plot(x,d, color='orange')
plt.plot(x,e, color='purple')
plt.plot(x,f, color='black')
plt.plot(x,g, color='gray')
plt.plot(x,h, color='gold')
plt.plot(x,i, color='brown')

plt.xticks(rotation=90)
plt.ylabel('Salary ($)')
plt.title('Salary Trend for a Registered Nurse')
plt.legend(['Seattle', 'National Average', 'Atlanta', 'Houston', 'NYC', 'LA', 'Philadelphia', 'SF', 'Chicago', 'Boston', 'Washington D.C.'],loc='center left', bbox_to_anchor=(1, 0.5))
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# Compare Accountant salary trends across regions
x = df_SEA_Accountant.Month
y = df_SEA_Accountant.Value
z = df_US_Accountant.Value
a = df_ATL_Accountant.Value
b = df_HOU_Accountant.Value
c = df_NYC_Accountant.Value
d = df_LA_Accountant.Value
e = df_PHIL_Accountant.Value
f = df_SF_Accountant.Value
g = df_CHI_Accountant.Value
h = df_BOS_Accountant.Value
i = df_DC_Accountant.Value

plt.plot(x,y, color='blue')
plt.plot(x,z, color='red')
plt.plot(x,a, color='green')
plt.plot(x,b, color='yellow')
plt.plot(x,c, color='pink')
plt.plot(x,d, color='orange')
plt.plot(x,e, color='purple')
plt.plot(x,f, color='black')
plt.plot(x,g, color='gray')
plt.plot(x,h, color='gold')
plt.plot(x,i, color='brown')

plt.xticks(rotation=90)
plt.ylabel('Salary ($)')
plt.title('Salary Trend for an Accountant')
plt.legend(['Seattle', 'National Average', 'Atlanta', 'Houston', 'NYC', 'LA', 'Philadelphia', 'SF', 'Chicago', 'Boston', 'Washington D.C.'],loc='center left', bbox_to_anchor=(1, 0.5))
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# Compare Sales Representative salary trends across regions
x = df_SEA_Sales_Rep.Month
y = df_SEA_Sales_Rep.Value
z = df_US_Sales_Rep.Value
a = df_ATL_Sales_Rep.Value
b = df_HOU_Sales_Rep.Value
c = df_NYC_Sales_Rep.Value
d = df_LA_Sales_Rep.Value
e = df_PHIL_Sales_Rep.Value
f = df_SF_Sales_Rep.Value
g = df_CHI_Sales_Rep.Value
h = df_BOS_Sales_Rep.Value
i = df_DC_Sales_Rep.Value

plt.plot(x,y, color='blue')
plt.plot(x,z, color='red')
plt.plot(x,a, color='green')
plt.plot(x,b, color='yellow')
plt.plot(x,c, color='pink')
plt.plot(x,d, color='orange')
plt.plot(x,e, color='purple')
plt.plot(x,f, color='black')
plt.plot(x,g, color='gray')
plt.plot(x,h, color='gold')
plt.plot(x,i, color='brown')

plt.xticks(rotation=90)
plt.ylabel('Salary ($)')
plt.title('Salary Trend for a Sales Representative')
plt.legend(['Seattle', 'National Average', 'Atlanta', 'Houston', 'NYC', 'LA', 'Philadelphia', 'SF', 'Chicago', 'Boston', 'Washington D.C.'],loc='center left', bbox_to_anchor=(1, 0.5))
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# Compare Professor salary trends across regions
x = df_SEA_Professor.Month
y = df_SEA_Professor.Value
z = df_US_Professor.Value
a = df_ATL_Professor.Value
b = df_HOU_Professor.Value
c = df_NYC_Professor.Value
d = df_LA_Professor.Value
e = df_PHIL_Professor.Value
f = df_SF_Professor.Value
g = df_CHI_Professor.Value
h = df_BOS_Professor.Value
i = df_DC_Professor.Value

plt.plot(x,y, color='blue')
plt.plot(x,z, color='red')
plt.plot(x,a, color='green')
plt.plot(x,b, color='yellow')
plt.plot(x,c, color='pink')
plt.plot(x,d, color='orange')
plt.plot(x,e, color='purple')
plt.plot(x,f, color='black')
plt.plot(x,g, color='gray')
plt.plot(x,h, color='gold')
plt.plot(x,i, color='brown')

plt.xticks(rotation=90)
plt.ylabel('Salary ($)')
plt.title('Salary Trend for a Professor')
plt.legend(['Seattle', 'National Average', 'Atlanta', 'Houston', 'NYC', 'LA', 'Philadelphia', 'SF', 'Chicago', 'Boston', 'Washington D.C.'],loc='center left', bbox_to_anchor=(1, 0.5))
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# Compare Data Scientist salary trends across regions
x = df_SEA_Data_Scientist.Month
y = df_SEA_Data_Scientist.Value
z = df_US_Data_Scientist.Value
a = df_ATL_Data_Scientist.Value
b = df_HOU_Data_Scientist.Value
c = df_NYC_Data_Scientist.Value
d = df_LA_Data_Scientist.Value
e = df_PHIL_Data_Scientist.Value
f = df_SF_Data_Scientist.Value
g = df_CHI_Data_Scientist.Value
h = df_BOS_Data_Scientist.Value
i = df_DC_Data_Scientist.Value

plt.plot(x,y, color='blue')
plt.plot(x,z, color='red')
plt.plot(x,a, color='green')
plt.plot(x,b, color='yellow')
plt.plot(x,c, color='pink')
plt.plot(x,d, color='orange')
plt.plot(x,e, color='purple')
plt.plot(x,f, color='black')
plt.plot(x,g, color='gray')
plt.plot(x,h, color='gold')
plt.plot(x,i, color='brown')

plt.xticks(rotation=90)
plt.ylabel('Salary ($)')
plt.title('Salary Trend for a Data Scientist')
plt.legend(['Seattle', 'National Average', 'Atlanta', 'Houston', 'NYC', 'LA', 'Philadelphia', 'SF', 'Chicago', 'Boston', 'Washington D.C.'],loc='center left', bbox_to_anchor=(1, 0.5))
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# Compare Teacher salary trends across regions
x = df_SEA_Teacher.Month
y = df_SEA_Teacher.Value
z = df_US_Teacher.Value
a = df_ATL_Teacher.Value
b = df_HOU_Teacher.Value
c = df_NYC_Teacher.Value
d = df_LA_Teacher.Value
e = df_PHIL_Teacher.Value
f = df_SF_Teacher.Value
g = df_CHI_Teacher.Value
h = df_BOS_Teacher.Value
i = df_DC_Teacher.Value

plt.plot(x,y, color='blue')
plt.plot(x,z, color='red')
plt.plot(x,a, color='green')
plt.plot(x,b, color='yellow')
plt.plot(x,c, color='pink')
plt.plot(x,d, color='orange')
plt.plot(x,e, color='purple')
plt.plot(x,f, color='black')
plt.plot(x,g, color='gray')
plt.plot(x,h, color='gold')
plt.plot(x,i, color='brown')

plt.xticks(rotation=90)
plt.ylabel('Salary ($)')
plt.title('Salary Trend for a Teacher')
plt.legend(['Seattle', 'National Average', 'Atlanta', 'Houston', 'NYC', 'LA', 'Philadelphia', 'SF', 'Chicago', 'Boston', 'Washington D.C.'],loc='center left', bbox_to_anchor=(1, 0.5))
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# Compare salary trends for Accountant across regions
x = df_US_Accountant.Month
y = df_US_Accountant.Value
z = df_US_Accountant.Value
a = df_ATL_Accountant.Value
b = df_HOU_Teacher.Value
c = df_NYC_Teacher.Value
d = df_LA_Teacher.Value
e = df_PHIL_Teacher.Value
f = df_SF_Teacher.Value
g = df_CHI_Teacher.Value
h = df_BOS_Teacher.Value
i = df_DC_Teacher.Value

plt.plot(x,y, color='blue')
plt.plot(x,z, color='red')
plt.plot(x,a, color='green')
plt.plot(x,b, color='yellow')
plt.plot(x,c, color='pink')
plt.plot(x,d, color='orange')
plt.plot(x,e, color='purple')
plt.plot(x,f, color='black')
plt.plot(x,g, color='gray')
plt.plot(x,h, color='gold')
plt.plot(x,i, color='brown')

plt.xticks(rotation=90)
plt.ylabel('Salary ($)')
plt.title('Salary Trend for an Accountant')
plt.legend(['National Average', 'Atlanta','Philadelphia'],loc='center left', bbox_to_anchor=(1, 0.5))
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# # Create datasets for job titles

# %%
# function creates dataframes for job titles and exports as csv
# Adjusts the month and year to a numeric value
# One-hot encodes the metropolitan areas
# Creates target variable
def Job_Title_Prep(dataframe, value, filename):
    dataframe["Month"] = dataframe[dataframe.columns[2:3]].replace('[-]', '', regex=True).astype(float)
    Metro_dummies = pd.get_dummies(dataframe["Metro"])
    dataframe["Atlanta"] = Metro_dummies["Atlanta"]
    dataframe["Boston"] = Metro_dummies["Boston"]
    dataframe["Chicago"] = Metro_dummies["Chicago"]
    dataframe["Houston"] = Metro_dummies["Houston"]
    dataframe["Los Angeles"] = Metro_dummies["Los Angeles"]
    dataframe["National"] = Metro_dummies["National"]
    dataframe["New York City"] = Metro_dummies["New York City"]
    dataframe["Philadelphia"] = Metro_dummies["Philadelphia"]
    dataframe["San Francisco"] = Metro_dummies["San Francisco"]
    dataframe["Seattle"] = Metro_dummies["Seattle"]
    dataframe["Washington DC"] = Metro_dummies["Washington DC"]
    dataframe['Value_split'] = dataframe['Value']
    dataframe.loc[dataframe.Value_split < value, 'Value_split'] = 0
    dataframe.loc[dataframe.Value_split > value, 'Value_split'] = 1
    dataframe.to_csv(filename)

# %%
# Run function on 12 job titles
Job_Title_Prep(df_RN,RN_mean,'df_RN.csv')
Job_Title_Prep(df_Data_Scientist,DataScientist_mean,'df_Data_Scientist.csv')
Job_Title_Prep(df_Accountant,Accountant_mean, 'df_Accountant.csv')
Job_Title_Prep(df_IT_Manager,ITMgr_mean,'df_IT_Manager.csv')
Job_Title_Prep(df_Sales_Rep,SalesRep_mean,'df_Sales_Rep.csv')
Job_Title_Prep(df_Professor,Professor_mean,'df_Professor.csv')
Job_Title_Prep(df_Teacher,Teadcher_mean,'df_Teacher.csv')
Job_Title_Prep(df_Software_Engineer,SoftwareEng_mean,'df_Software_Engineer.csv')
Job_Title_Prep(df_Project_Mgr,ProjectMgr_mean,'df_Project_Mgr.csv')
Job_Title_Prep(df_Financial_Analyst,FinAnalyst_mean,'df_Financial_Analyst.csv')
Job_Title_Prep(df_Data_Analyst,DataAnalyst_mean,'df_Data_Analyst.csv')
Job_Title_Prep(df_Graphic_Designer,GraphicDesigner_mean,'df_Graphic_Designer.csv')
# Out:
# /Users/davidsuffolk/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/davidsuffolk/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/davidsuffolk/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# # Prepare Data Scientist Data for Binned Target Variables

# %%
# Explore distribution of salaries to prepare bins
df_Data_Scientist.Value.hist()

# %%
# Create new colum for bin values
# Fill in column with bin values based on salary value
df_Data_Scientist['Value_bins'] = df_Data_Scientist['Value']
df_Data_Scientist.loc[df_Data_Scientist.Value < 100000, 'Value_bins'] = 0
df_Data_Scientist.loc[(df_Data_Scientist.Value < 110000) & (df_Data_Scientist.Value > 100000), 'Value_bins'] = 1
df_Data_Scientist.loc[(df_Data_Scientist.Value < 120000) & (df_Data_Scientist.Value > 110000), 'Value_bins'] = 2
df_Data_Scientist.loc[(df_Data_Scientist.Value < 130000) & (df_Data_Scientist.Value > 120000), 'Value_bins'] = 3
df_Data_Scientist.loc[df_Data_Scientist.Value > 130000, 'Value_bins'] = 4
# Out:
# /Users/davidsuffolk/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# Explore dataframe
df_Data_Scientist.head()
# Out:
#              Metro Dimension Type     Month       Dimension          Measure  \
# 89        National      Job Title  201707.0  Data Scientist  Median Base Pay
# 173        Atlanta      Job Title  201707.0  Data Scientist  Median Base Pay
# 257  New York City      Job Title  201707.0  Data Scientist  Median Base Pay
# 341    Los Angeles      Job Title  201707.0  Data Scientist  Median Base Pay
# 425   Philadelphia      Job Title  201707.0  Data Scientist  Median Base Pay
#
#         Value  YoY  Atlanta  Boston  Chicago  Houston  Los Angeles  National  \
# 89    95217.0  2.0        0       0        0        0            0         1
# 173   93069.0  1.6        1       0        0        0            0         0
# 257  112474.0  2.2        0       0        0        0            0         0
# 341  114061.0  1.3        0       0        0        0            1         0
# 425   94540.0  2.1        0       0        0        0            0         0
#
# ...

# %%
# Verify bins values
df_Data_Scientist.Value_bins.unique()
# Out:
# array([0., 2., 3., 4., 1.])

# %%
# Verify distribution of bins values
df_Data_Scientist.Value_bins.hist()

# %%
# Export to CSV
df_Data_Scientist.to_csv('df_Data_Scientist_Bins.csv')

# %% [markdown]
# # Prepare dataset with Job Titles as Variables

# %%
# Create new dataframe with unneeded values removed
df_2 = df[df["Dimension"] != "U.S. Median Pay"]
df_2 = df_2[df_2["Dimension"] != "Metro Median Pay"]
df_2 = df_2[df_2["Dimension"] != "U.S. Job Openings"]
df_2 = df_2[df_2["Dimension"] != "Metro Job Openings"]
df_2 = df_2[df_2["Dimension"] != "Metro Median Base Pay"]
df_2 = df_2[df_2["Dimension"] != "1001-5000"]
df_2 = df_2[df_2["Dimension"] != "<51"]
df_2 = df_2[df_2["Dimension"] != "201-500"]
df_2 = df_2[df_2["Dimension"] != "5000+"]
df_2 = df_2[df_2["Dimension"] != "501-1000"]
df_2 = df_2[df_2["Dimension"] != "51-200"]
df_2 = df_2[df_2["Dimension"] != "Job Openings"]
df_2 = df_2[df_2["Dimension"] != "Labor Force Size"]
df_2 = df_2[df_2["Dimension"] != "Total Employment"]
df_2 = df_2[df_2["Dimension"] != "Unemployment Rate"]
df_2 = df_2[df_2["Dimension"] != "Other"]

# %%
# For bins, explore maximum value
df_2.Value.max()
# Out:
# 924254.0

# %%
# For bins, explore minimum value
df_2.Value.min()
# Out:
# 32.0

# %%
# Review the average salary across all jobs
df_2.Value.mean()
# Out:
# 58956.593978748526

# %%
# Create 28 bins for salary values across all job titles
df_2['Value_bins'] = df_2['Value']
df_2.loc[df_2.Value < 20000, 'Value_bins'] = 0
df_2.loc[(df_2.Value < 25000) & (df_2.Value > 20000), 'Value_bins'] = 1
df_2.loc[(df_2.Value < 30000) & (df_2.Value > 25000), 'Value_bins'] = 2
df_2.loc[(df_2.Value < 35000) & (df_2.Value > 30000), 'Value_bins'] = 3
df_2.loc[(df_2.Value < 40000) & (df_2.Value > 35000), 'Value_bins'] = 4
df_2.loc[(df_2.Value < 45000) & (df_2.Value > 40000), 'Value_bins'] = 5
df_2.loc[(df_2.Value < 50000) & (df_2.Value > 45000), 'Value_bins'] = 6
df_2.loc[(df_2.Value < 55000) & (df_2.Value > 50000), 'Value_bins'] = 7
df_2.loc[(df_2.Value < 60000) & (df_2.Value > 55000), 'Value_bins'] = 8
df_2.loc[(df_2.Value < 65000) & (df_2.Value > 60000), 'Value_bins'] = 9
df_2.loc[(df_2.Value < 70000) & (df_2.Value > 65000), 'Value_bins'] = 10
df_2.loc[(df_2.Value < 75000) & (df_2.Value > 70000), 'Value_bins'] = 11
df_2.loc[(df_2.Value < 80000) & (df_2.Value > 75000), 'Value_bins'] = 12
df_2.loc[(df_2.Value < 85000) & (df_2.Value > 80000), 'Value_bins'] = 13
df_2.loc[(df_2.Value < 90000) & (df_2.Value > 85000), 'Value_bins'] = 14
df_2.loc[(df_2.Value < 95000) & (df_2.Value > 90000), 'Value_bins'] = 15
df_2.loc[(df_2.Value < 100000) & (df_2.Value > 95000), 'Value_bins'] = 16
df_2.loc[(df_2.Value < 105000) & (df_2.Value > 100000), 'Value_bins'] = 17
df_2.loc[(df_2.Value < 110000) & (df_2.Value > 105000), 'Value_bins'] = 18
df_2.loc[(df_2.Value < 115000) & (df_2.Value > 110000), 'Value_bins'] = 19
df_2.loc[(df_2.Value < 120000) & (df_2.Value > 115000), 'Value_bins'] = 20
df_2.loc[(df_2.Value < 125000) & (df_2.Value > 120000), 'Value_bins'] = 21
df_2.loc[(df_2.Value < 130000) & (df_2.Value > 125000), 'Value_bins'] = 22
df_2.loc[(df_2.Value < 135000) & (df_2.Value > 130000), 'Value_bins'] = 23
df_2.loc[(df_2.Value < 140000) & (df_2.Value > 135000), 'Value_bins'] = 24
df_2.loc[(df_2.Value < 145000) & (df_2.Value > 140000), 'Value_bins'] = 25
df_2.loc[(df_2.Value < 150000) & (df_2.Value > 145000), 'Value_bins'] = 26
df_2.loc[df_2.Value > 150000, 'Value_bins'] = 27

# %%
# Review dataframe
df_2[0:10]
# Out:
#        Metro Dimension Type    Month                 Dimension  \
# 61  National      Job Title  2017-07         Software Engineer
# 62  National      Job Title  2017-07        Programmer Analyst
# 63  National      Job Title  2017-07                Consultant
# 64  National      Job Title  2017-07           Project Manager
# 65  National      Job Title  2017-07             Store Manager
# 66  National      Job Title  2017-07          Business Analyst
# 67  National      Job Title  2017-07                   Cashier
# 68  National      Job Title  2017-07         Financial Analyst
# 69  National      Job Title  2017-07  Administrative Assistant
# 70  National      Job Title  2017-07                Accountant
#
#             Measure    Value  YoY  Value_bins
# 61  Median Base Pay  85380.0  2.2        14.0
# 62  Median Base Pay  67260.0  1.9        10.0
# 63  Median Base Pay  73521.0  0.5        11.0
# 64  Median Base Pay  72762.0  0.2        11.0
# ...

# %%
# Convert date to numeric value and review
df_2["Month"] = df_2[df_2.columns[2:3]].replace('[-]', '', regex=True).astype(float)
df_2[0:10]
# Out:
#        Metro Dimension Type     Month                 Dimension  \
# 61  National      Job Title  201707.0         Software Engineer
# 62  National      Job Title  201707.0        Programmer Analyst
# 63  National      Job Title  201707.0                Consultant
# 64  National      Job Title  201707.0           Project Manager
# 65  National      Job Title  201707.0             Store Manager
# 66  National      Job Title  201707.0          Business Analyst
# 67  National      Job Title  201707.0                   Cashier
# 68  National      Job Title  201707.0         Financial Analyst
# 69  National      Job Title  201707.0  Administrative Assistant
# 70  National      Job Title  201707.0                Accountant
#
#             Measure    Value  YoY  Value_bins
# 61  Median Base Pay  85380.0  2.2        14.0
# 62  Median Base Pay  67260.0  1.9        10.0
# 63  Median Base Pay  73521.0  0.5        11.0
# 64  Median Base Pay  72762.0  0.2        11.0
# ...

# %%
# Create dummies for all job titles for one-hot encoding
dimension_dummies = pd.get_dummies(df_2["Dimension"])
dimension_dummies
# Out:
#       Accountant  Accounting & Legal  Administrative Assistant  \
# 61             0                   0                         0
# 62             0                   0                         0
# 63             0                   0                         0
# 64             0                   0                         0
# 65             0                   0                         0
# ...          ...                 ...                       ...
# 4963           0                   0                         0
# 4970           0                   0                         0
# 4977           0                   0                         0
# 4984           0                   0                         0
# 4991           0                   0                         0
#
#       Aerospace & Defense  Architecture & Civil Engineering  \
# 61                      0                                 0
# 62                      0                                 0
# ...

# %%
# Create columns in dataframe that uses one-hot encoding for 12 job titles
df_2["Registered Nurse"] = dimension_dummies["Registered Nurse"]
df_2["Data Scientist"] = dimension_dummies["Data Scientist"]
df_2["Accountant"] = dimension_dummies["Accountant"]
df_2["IT Manager"] = dimension_dummies["IT Manager"]
df_2["Sales Representative"] = dimension_dummies["Sales Representative"]
df_2["Professor"] = dimension_dummies["Professor"]
df_2["Teacher"] = dimension_dummies["Teacher"]
df_2["Software Engineer"] = dimension_dummies["Software Engineer"]
df_2["Project Manager"] = dimension_dummies["Project Manager"]
df_2["Financial Analyst"] = dimension_dummies["Financial Analyst"]
df_2["Data Analyst"] = dimension_dummies["Data Analyst"]
df_2["Graphic Designer"] = dimension_dummies["Graphic Designer"]

# %%
# Filter out only the rows that contain the 12 job titles
jobs = ["Registered Nurse","Data Scientist","Accountant","IT Manager","Sales Representative","Professor","Teacher","Software Engineer",
       "Project Manager","Financial Analyst","Data Analyst","Graphic Designer"]
df_2= df_2[df_2.Dimension.isin(jobs)]
df_2.Dimension.unique()
# Out:
# array(['Software Engineer', 'Project Manager', 'Financial Analyst',
#        'Accountant', 'Sales Representative', 'Professor',
#        'Registered Nurse', 'Teacher', 'Graphic Designer',
#        'Data Scientist', 'Data Analyst', 'IT Manager'], dtype=object)

# %%
# Add columsn for metropolitan values
Metro_dummies = pd.get_dummies(df_2["Metro"])
Metro_dummies.head()
# Out:
#     Atlanta  Boston  Chicago  Houston  Los Angeles  National  New York City  \
# 61        0       0        0        0            0         1              0
# 64        0       0        0        0            0         1              0
# 68        0       0        0        0            0         1              0
# 70        0       0        0        0            0         1              0
# 71        0       0        0        0            0         1              0
#
#     Philadelphia  San Francisco  Seattle  Washington DC
# 61             0              0        0              0
# 64             0              0        0              0
# 68             0              0        0              0
# 70             0              0        0              0
# 71             0              0        0              0

# %%
# Add one-hot encoded metropolitan values to dataframe
df_2["Atlanta"] = Metro_dummies["Atlanta"]
df_2["Boston"] = Metro_dummies["Boston"]
df_2["Chicago"] = Metro_dummies["Chicago"]
df_2["Houston"] = Metro_dummies["Houston"]
df_2["Los Angeles"] = Metro_dummies["Los Angeles"]
df_2["National"] = Metro_dummies["National"]
df_2["New York City"] = Metro_dummies["New York City"]
df_2["Philadelphia"] = Metro_dummies["Philadelphia"]
df_2["San Francisco"] = Metro_dummies["San Francisco"]
df_2["Seattle"] = Metro_dummies["Seattle"]
df_2["Washington DC"] = Metro_dummies["Washington DC"]

# %%
# Review dataframe
df_2[0:20]
# Out:
#         Metro Dimension Type     Month             Dimension          Measure  \
# 61   National      Job Title  201707.0     Software Engineer  Median Base Pay
# 64   National      Job Title  201707.0       Project Manager  Median Base Pay
# 68   National      Job Title  201707.0     Financial Analyst  Median Base Pay
# 70   National      Job Title  201707.0            Accountant  Median Base Pay
# 71   National      Job Title  201707.0  Sales Representative  Median Base Pay
# 72   National      Job Title  201707.0             Professor  Median Base Pay
# 73   National      Job Title  201707.0      Registered Nurse  Median Base Pay
# 78   National      Job Title  201707.0               Teacher  Median Base Pay
# 86   National      Job Title  201707.0      Graphic Designer  Median Base Pay
# 89   National      Job Title  201707.0        Data Scientist  Median Base Pay
# 91   National      Job Title  201707.0          Data Analyst  Median Base Pay
# ...

# %%
# Export to csv file
df_2.to_csv('df_all_final.csv')
